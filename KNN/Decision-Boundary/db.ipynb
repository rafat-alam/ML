# %% [markdown]
# # Decision Boundary
#
# ## Points
#   1. We can draw decision boundary for all the classification algorithms including Neural Networks.
#   2. Decision boundary are not always clear cut.
#   3. It's known as __Vornoi Diagram__ when we plot region for every seed respectively.

# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creating a Sample Meshgrid

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6, 7])

xx, yy = np.meshgrid(a, b)
print(xx)
print(yy)
# Out:
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]
#  [1 2 3]]
# [[4 4 4]
#  [5 5 5]
#  [6 6 6]
#  [7 7 7]]

# %%
input_array = np.array([xx.ravel(), yy.ravel()])
print(input_array)

input_array = input_array.T
print(input_array)
# Out:
# [[1 2 3 1 2 3 1 2 3 1 2 3]
#  [4 4 4 5 5 5 6 6 6 7 7 7]]
# [[1 4]
#  [2 4]
#  [3 4]
#  [1 5]
#  [2 5]
#  [3 5]
#  [1 6]
#  [2 6]
#  [3 6]
#  [1 7]
#  [2 7]
#  [3 7]]

# %% [markdown]
# ### Preprocessing Before Meshgrid Created

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
x = data.iloc[:,2:4]
y = data.iloc[:,-1].values

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 17)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %% [markdown]
# ### Creating a Meshgrid

# %%
a = np.arange(start = x_train[:,0].min() - 1, stop = x_train[:,0].max() + 1, step = 0.01)
print(a.shape)

b = np.arange(start = x_train[:,1].min() - 1, stop = x_train[:,1].max() + 1, step = 0.01)
print(b.shape)

xx, yy = np.meshgrid(a, b)
print(xx.shape)
print(yy.shape)
# Out:
# (602,)
# (597,)
# (597, 602)
# (597, 602)

# %% [markdown]
# ### Plotting Decision Boundary

# %%
input_array = np.array([xx.ravel(), yy.ravel()]).T
input_array.shape
# Out:
# (359394, 2)

# %%
label = knn.predict(input_array)
label.shape
# Out:
# (359394,)

# %%
plt.contourf(xx, yy, label.reshape(xx.shape))

# %%
plt.contourf(xx, yy, label.reshape(xx.shape))
plt.scatter(x_train[:,0], x_train[:,1], c = y_train)

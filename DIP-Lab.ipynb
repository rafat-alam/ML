# %% [markdown]
# <a href="https://colab.research.google.com/github/rafat-alam/ML/blob/main/DIP-Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rafat")e
# Out:
# rafat
